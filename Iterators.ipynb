# %%
try :
    n=range(1,5)
    i=iter(n)
    print(next(i))
    print(next(i))
    print(next(i))
    print(next(i))
    print(next(i)) 
except:
    print("StopIteration!")
# Out:
# 1
# 2
# 3
# 4
# StopIteration!

# %%
l=[1,2,4,5,6,8]
l=iter(l)
print(next(l))
print(next(l))
print(next(l))
# Out:
# 1
# 2
# 4
